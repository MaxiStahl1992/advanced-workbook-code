# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import yfinance as yf
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from statsmodels.tsa.api import VAR

# %%
# Stationarity test
def test_stationarity(timeseries, significance_level=0.05):
    adf_result = adfuller(timeseries.diff().dropna())
    return adf_result[1] < significance_level

# %%
# Lag Selection
def select_lag(data, max_lag):
    model = VAR(data)
    best_aic = float('inf')
    best_order = 0
    for lag in range(1, max_lag + 1):
        result = model.fit(lag)
        if result.aic < best_aic:
            best_aic = result.aic
            best_order = lag
    return best_order

# %%
# Granger Causality Test
def granger_causality_test(df, tickers, periods, max_lag=12):
    results = pd.DataFrame()
    for period in periods:
        data = df[df.columns]
        for stock1 in tickers:
            for stock2 in tickers:
                if stock1 != stock2:
                    gc_test = grangercausalitytests(data[[stock1, stock2]], maxlag=select_lag(data[[stock1, stock2]], max_lag))
                    for lag in gc_test:
                        f_test_values = gc_test[lag][0]['ssr_ftest']
                        p_values = f_test_values[1]
                        results.loc[f'{stock2} -> {stock1}, ({period})', f'lag_{lag}'] = p_values
    return results

# %%
def select_data(data, period):
    if period == '5y':
        return data.tail(5 * 252) 
    elif period == '1y':
       return data.tail(252)
    elif period == '1m':
        return data.tail(20) 
    else:
        raise ValueError("Invalid period. Supported values: '5y', '1y', '1m'")

def visualize_stock_tickers(data, tickers, period):
    num_pairs = len(tickers) * (len(tickers) - 1) // 2
    rows = num_pairs // 3 + 1
    cols = 2

    fig, axs = plt.subplots(rows, cols, figsize=(15, 6 * rows)) 
    axs = axs.flatten()

    pair_index = 0
    for i, stock1 in enumerate(tickers):
        for stock2 in tickers[i+1:]:
            if stock1 != stock2:
                if pair_index >= len(axs):
                    break;
                
                ax = axs[pair_index]
                
                period_data = select_data(data, period)
            
                if period == '1m':
                    my_fmt = mdates.DateFormatter('%m-%d')
                    ax.xaxis.set_major_formatter(my_fmt)
               
                ax.plot(period_data[stock1], label=stock1)
                ax.plot(period_data[stock2], label=stock2)

                ax.set_xlabel('Time')
                ax.set_ylabel('Price')
                ax.legend()
                ax.set_title(f'{stock1} vs. {stock2} Price Over Time ({period})')

                pair_index += 1

    plt.tight_layout()
    plt.show()

# %%
def visualize_stock_pairs(stock1, stock2, period):
    period_data_stock1 = select_data(stock1, period)
    period_data_stock2 = select_data(stock2, period)
    
    if period == '1m':
                    my_fmt = mdates.DateFormatter('%m-%d')
                    plt.gca().xaxis.set_major_formatter(my_fmt)

    plt.plot(period_data_stock1, label=stock1.name)
    plt.plot(period_data_stock2, label=stock2.name)
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.title(f'{stock1.name} vs. {stock2.name} Price Over Time ({period})')
    plt.legend()
    plt.show()

# %%
def highlight_table_cells(val, threshold=0.05):
    color = 'yellow' if val < threshold else 'transparent'
    return f'background-color: {color}'

# %%
# Data setup
tickers = ['AAPL', 'MSFT', 'GOOGL', 'META']
all_periods = ['5y', '1y', '1m']
data = yf.download(tickers, period='5y', interval='1d')['Adj Close']
data_log = data.apply(np.log)
data_log.index = data.index.to_period('D')
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
visualize_stock_pairs(data['AAPL'], data['MSFT'], '5y')
visualize_stock_pairs(data['AAPL'], data['MSFT'], '1y')
visualize_stock_pairs(data['AAPL'], data['MSFT'], '1m')

# %%
visualize_stock_tickers(data, tickers, '5y')
visualize_stock_tickers(data, tickers, '1y')
visualize_stock_tickers(data, tickers, '1m')

# %%
# Data analysis
for stock in tickers:
    if not test_stationarity(data[stock]):
        print(f'{stock} is not stationary')

results_df = granger_causality_test(data_log, tickers, periods=all_periods, max_lag=12)
styled_df = results_df.style.applymap(highlight_table_cells)
styled_df
# Out:
# ['5y', '1y', '1m']
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2707  , p=0.6029  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.2714  , p=0.6024  , df=1
# likelihood ratio test: chi2=0.2713  , p=0.6024  , df=1
# parameter F test:         F=0.2707  , p=0.6029  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3085  , p=0.2706  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.6275  , p=0.2688  , df=2
# likelihood ratio test: chi2=2.6248  , p=0.2692  , df=2
# parameter F test:         F=1.3085  , p=0.2706  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8632  , p=0.4596  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.6042  , p=0.4568  , df=3
# likelihood ratio test: chi2=2.6015  , p=0.4572  , df=3
# parameter F test:         F=0.8632  , p=0.4596  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4792  , p=0.0424  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=9.9884  , p=0.0406  , df=4
# likelihood ratio test: chi2=9.9488  , p=0.0413  , df=4
# parameter F test:         F=2.4792  , p=0.0424  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3035  , p=0.0427  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=11.6196 , p=0.0404  , df=5
# likelihood ratio test: chi2=11.5661 , p=0.0412  , df=5
# parameter F test:         F=2.3035  , p=0.0427  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4010  , p=0.0260  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=14.5569 , p=0.0240  , df=6
# likelihood ratio test: chi2=14.4730 , p=0.0248  , df=6
# parameter F test:         F=2.4010  , p=0.0260  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9420  , p=0.0046  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=20.8435 , p=0.0040  , df=7
# likelihood ratio test: chi2=20.6719 , p=0.0043  , df=7
# parameter F test:         F=2.9420  , p=0.0046  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.8877  , p=0.0002  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=31.5302 , p=0.0001  , df=8
# likelihood ratio test: chi2=31.1394 , p=0.0001  , df=8
# parameter F test:         F=3.8877  , p=0.0002  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.3194  , p=0.0005  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=30.3359 , p=0.0004  , df=9
# likelihood ratio test: chi2=29.9737 , p=0.0004  , df=9
# parameter F test:         F=3.3194  , p=0.0005  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.2042  , p=0.0004  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=32.5899 , p=0.0003  , df=10
# likelihood ratio test: chi2=32.1720 , p=0.0004  , df=10
# parameter F test:         F=3.2042  , p=0.0004  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.8318  , p=0.0012  , df_denom=1225, df_num=11
# ssr based chi2 test:   chi2=31.7348 , p=0.0008  , df=11
# likelihood ratio test: chi2=31.3380 , p=0.0010  , df=11
# parameter F test:         F=2.8318  , p=0.0012  , df_denom=1225, df_num=11
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2589  , p=0.6109  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.2596  , p=0.6104  , df=1
# likelihood ratio test: chi2=0.2595  , p=0.6104  , df=1
# parameter F test:         F=0.2589  , p=0.6109  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1668  , p=0.3117  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.3430  , p=0.3099  , df=2
# likelihood ratio test: chi2=2.3408  , p=0.3102  , df=2
# parameter F test:         F=1.1668  , p=0.3117  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9525  , p=0.4145  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.8734  , p=0.4116  , df=3
# likelihood ratio test: chi2=2.8702  , p=0.4121  , df=3
# parameter F test:         F=0.9525  , p=0.4145  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0517  , p=0.3792  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=4.2372  , p=0.3749  , df=4
# likelihood ratio test: chi2=4.2301  , p=0.3758  , df=4
# parameter F test:         F=1.0517  , p=0.3792  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1584  , p=0.3276  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=5.8434  , p=0.3218  , df=5
# likelihood ratio test: chi2=5.8298  , p=0.3231  , df=5
# parameter F test:         F=1.1584  , p=0.3276  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0378  , p=0.3989  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=6.2920  , p=0.3913  , df=6
# likelihood ratio test: chi2=6.2763  , p=0.3930  , df=6
# parameter F test:         F=1.0378  , p=0.3989  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.3200  , p=0.0236  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=16.4372 , p=0.0214  , df=7
# likelihood ratio test: chi2=16.3302 , p=0.0223  , df=7
# parameter F test:         F=2.3200  , p=0.0236  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3396  , p=0.0170  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=18.9745 , p=0.0150  , df=8
# likelihood ratio test: chi2=18.8320 , p=0.0158  , df=8
# parameter F test:         F=2.3396  , p=0.0170  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0661  , p=0.0297  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=18.8817 , p=0.0262  , df=9
# likelihood ratio test: chi2=18.7406 , p=0.0275  , df=9
# parameter F test:         F=2.0661  , p=0.0297  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8301  , p=0.0513  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=18.6135 , p=0.0455  , df=10
# likelihood ratio test: chi2=18.4762 , p=0.0474  , df=10
# parameter F test:         F=1.8301  , p=0.0513  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0001  , p=0.9927  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0001  , p=0.9927  , df=1
# likelihood ratio test: chi2=0.0001  , p=0.9927  , df=1
# parameter F test:         F=0.0001  , p=0.9927  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2649  , p=0.7673  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=0.5319  , p=0.7665  , df=2
# likelihood ratio test: chi2=0.5318  , p=0.7665  , df=2
# parameter F test:         F=0.2649  , p=0.7673  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2707  , p=0.8465  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=0.8168  , p=0.8455  , df=3
# likelihood ratio test: chi2=0.8165  , p=0.8455  , df=3
# parameter F test:         F=0.2707  , p=0.8465  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2716  , p=0.8964  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=1.0941  , p=0.8952  , df=4
# likelihood ratio test: chi2=1.0936  , p=0.8953  , df=4
# parameter F test:         F=0.2716  , p=0.8964  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5735  , p=0.1646  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=7.9373  , p=0.1597  , df=5
# likelihood ratio test: chi2=7.9123  , p=0.1611  , df=5
# parameter F test:         F=1.5735  , p=0.1646  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4841  , p=0.1800  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=8.9980  , p=0.1737  , df=6
# likelihood ratio test: chi2=8.9659  , p=0.1755  , df=6
# parameter F test:         F=1.4841  , p=0.1800  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1907  , p=0.3049  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=8.4357  , p=0.2957  , df=7
# likelihood ratio test: chi2=8.4074  , p=0.2980  , df=7
# parameter F test:         F=1.1907  , p=0.3049  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1738  , p=0.3114  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=9.5200  , p=0.3003  , df=8
# likelihood ratio test: chi2=9.4839  , p=0.3031  , df=8
# parameter F test:         F=1.1738  , p=0.3114  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2830  , p=0.2414  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=11.7254 , p=0.2292  , df=9
# likelihood ratio test: chi2=11.6707 , p=0.2325  , df=9
# parameter F test:         F=1.2830  , p=0.2414  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2785  , p=0.2374  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=13.0036 , p=0.2235  , df=10
# likelihood ratio test: chi2=12.9363 , p=0.2273  , df=10
# parameter F test:         F=1.2785  , p=0.2374  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0086  , p=0.9262  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0086  , p=0.9261  , df=1
# likelihood ratio test: chi2=0.0086  , p=0.9261  , df=1
# parameter F test:         F=0.0086  , p=0.9262  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5590  , p=0.2107  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=3.1305  , p=0.2090  , df=2
# likelihood ratio test: chi2=3.1266  , p=0.2094  , df=2
# parameter F test:         F=1.5590  , p=0.2107  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0732  , p=0.3594  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=3.2377  , p=0.3564  , df=3
# likelihood ratio test: chi2=3.2336  , p=0.3570  , df=3
# parameter F test:         F=1.0732  , p=0.3594  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.5479  , p=0.0378  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=10.2652 , p=0.0362  , df=4
# likelihood ratio test: chi2=10.2235 , p=0.0368  , df=4
# parameter F test:         F=2.5479  , p=0.0378  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3494  , p=0.0390  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=11.8508 , p=0.0369  , df=5
# likelihood ratio test: chi2=11.7952 , p=0.0377  , df=5
# parameter F test:         F=2.3494  , p=0.0390  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0256  , p=0.0595  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=12.2811 , p=0.0560  , df=6
# likelihood ratio test: chi2=12.2213 , p=0.0572  , df=6
# parameter F test:         F=2.0256  , p=0.0595  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6128  , p=0.1276  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=11.4268 , p=0.1211  , df=7
# likelihood ratio test: chi2=11.3750 , p=0.1231  , df=7
# parameter F test:         F=1.6128  , p=0.1276  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6555  , p=0.1050  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=13.4261 , p=0.0980  , df=8
# likelihood ratio test: chi2=13.3545 , p=0.1002  , df=8
# parameter F test:         F=1.6555  , p=0.1050  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3078  , p=0.2279  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=11.9518 , p=0.2160  , df=9
# likelihood ratio test: chi2=11.8950 , p=0.2193  , df=9
# parameter F test:         F=1.3078  , p=0.2279  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3429  , p=0.2022  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=13.6586 , p=0.1891  , df=10
# likelihood ratio test: chi2=13.5844 , p=0.1928  , df=10
# parameter F test:         F=1.3429  , p=0.2022  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.5893  , p=0.0960  , df_denom=1225, df_num=11
# ssr based chi2 test:   chi2=17.8108 , p=0.0861  , df=11
# likelihood ratio test: chi2=17.6849 , p=0.0892  , df=11
# parameter F test:         F=1.5893  , p=0.0960  , df_denom=1225, df_num=11
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7347  , p=0.3915  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.7365  , p=0.3908  , df=1
# likelihood ratio test: chi2=0.7363  , p=0.3909  , df=1
# parameter F test:         F=0.7347  , p=0.3915  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3027  , p=0.2722  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.6158  , p=0.2704  , df=2
# likelihood ratio test: chi2=2.6131  , p=0.2708  , df=2
# parameter F test:         F=1.3027  , p=0.2722  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9189  , p=0.4310  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.7723  , p=0.4281  , df=3
# likelihood ratio test: chi2=2.7692  , p=0.4286  , df=3
# parameter F test:         F=0.9189  , p=0.4310  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.5151  , p=0.0400  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=10.1332 , p=0.0382  , df=4
# likelihood ratio test: chi2=10.0925 , p=0.0389  , df=4
# parameter F test:         F=2.5151  , p=0.0400  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9813  , p=0.0787  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=9.9942  , p=0.0754  , df=5
# likelihood ratio test: chi2=9.9546  , p=0.0765  , df=5
# parameter F test:         F=1.9813  , p=0.0787  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6138  , p=0.1397  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=9.7843  , p=0.1340  , df=6
# likelihood ratio test: chi2=9.7463  , p=0.1357  , df=6
# parameter F test:         F=1.6138  , p=0.1397  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4846  , p=0.1686  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=10.5184 , p=0.1610  , df=7
# likelihood ratio test: chi2=10.4745 , p=0.1632  , df=7
# parameter F test:         F=1.4846  , p=0.1686  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3133  , p=0.2325  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=10.6514 , p=0.2222  , df=8
# likelihood ratio test: chi2=10.6063 , p=0.2250  , df=8
# parameter F test:         F=1.3133  , p=0.2325  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1199  , p=0.3451  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=10.2347 , p=0.3318  , df=9
# likelihood ratio test: chi2=10.1930 , p=0.3351  , df=9
# parameter F test:         F=1.1199  , p=0.3451  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9945  , p=0.4461  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=10.1147 , p=0.4305  , df=10
# likelihood ratio test: chi2=10.0740 , p=0.4340  , df=10
# parameter F test:         F=0.9945  , p=0.4461  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0115  , p=0.9145  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0116  , p=0.9144  , df=1
# likelihood ratio test: chi2=0.0116  , p=0.9144  , df=1
# parameter F test:         F=0.0115  , p=0.9145  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1207  , p=0.8863  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=0.2424  , p=0.8858  , df=2
# likelihood ratio test: chi2=0.2424  , p=0.8858  , df=2
# parameter F test:         F=0.1207  , p=0.8863  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1236  , p=0.9462  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=0.3727  , p=0.9458  , df=3
# likelihood ratio test: chi2=0.3727  , p=0.9458  , df=3
# parameter F test:         F=0.1236  , p=0.9462  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2403  , p=0.9156  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=0.9681  , p=0.9146  , df=4
# likelihood ratio test: chi2=0.9677  , p=0.9147  , df=4
# parameter F test:         F=0.2403  , p=0.9156  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2495  , p=0.9402  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=1.2585  , p=0.9391  , df=5
# likelihood ratio test: chi2=1.2579  , p=0.9392  , df=5
# parameter F test:         F=0.2495  , p=0.9402  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1779  , p=0.9829  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=1.0787  , p=0.9825  , df=6
# likelihood ratio test: chi2=1.0783  , p=0.9825  , df=6
# parameter F test:         F=0.1779  , p=0.9829  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1972  , p=0.9861  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=1.3973  , p=0.9857  , df=7
# likelihood ratio test: chi2=1.3965  , p=0.9857  , df=7
# parameter F test:         F=0.1972  , p=0.9861  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2044  , p=0.9902  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=1.6580  , p=0.9898  , df=8
# likelihood ratio test: chi2=1.6569  , p=0.9898  , df=8
# parameter F test:         F=0.2044  , p=0.9902  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.2088  , p=0.9932  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=1.9083  , p=0.9928  , df=9
# likelihood ratio test: chi2=1.9068  , p=0.9929  , df=9
# parameter F test:         F=0.2088  , p=0.9932  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.2926  , p=0.9830  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=2.9763  , p=0.9820  , df=10
# likelihood ratio test: chi2=2.9727  , p=0.9821  , df=10
# parameter F test:         F=0.2926  , p=0.9830  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0170  , p=0.1558  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=2.0218  , p=0.1551  , df=1
# likelihood ratio test: chi2=2.0202  , p=0.1552  , df=1
# parameter F test:         F=2.0170  , p=0.1558  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.7663  , p=0.0087  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=9.5707  , p=0.0084  , df=2
# likelihood ratio test: chi2=9.5345  , p=0.0085  , df=2
# parameter F test:         F=4.7663  , p=0.0087  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1666  , p=0.0237  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=9.5531  , p=0.0228  , df=3
# likelihood ratio test: chi2=9.5170  , p=0.0232  , df=3
# parameter F test:         F=3.1666  , p=0.0237  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3369  , p=0.0536  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=9.4150  , p=0.0515  , df=4
# likelihood ratio test: chi2=9.3799  , p=0.0523  , df=4
# parameter F test:         F=2.3369  , p=0.0536  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0381  , p=0.0708  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=10.2807 , p=0.0677  , df=5
# likelihood ratio test: chi2=10.2388 , p=0.0687  , df=5
# parameter F test:         F=2.0381  , p=0.0708  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7124  , p=0.1146  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=10.3819 , p=0.1095  , df=6
# likelihood ratio test: chi2=10.3392 , p=0.1111  , df=6
# parameter F test:         F=1.7124  , p=0.1146  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3215  , p=0.2362  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=9.3629  , p=0.2276  , df=7
# likelihood ratio test: chi2=9.3281  , p=0.2300  , df=7
# parameter F test:         F=1.3215  , p=0.2362  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4909  , p=0.1558  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=12.0917 , p=0.1472  , df=8
# likelihood ratio test: chi2=12.0336 , p=0.1497  , df=8
# parameter F test:         F=1.4909  , p=0.1558  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4016  , p=0.1823  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=12.8093 , p=0.1714  , df=9
# likelihood ratio test: chi2=12.7441 , p=0.1745  , df=9
# parameter F test:         F=1.4016  , p=0.1823  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7385  , p=0.0676  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=17.6818 , p=0.0606  , df=10
# likelihood ratio test: chi2=17.5578 , p=0.0629  , df=10
# parameter F test:         F=1.7385  , p=0.0676  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.7071  , p=0.0170  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=5.7207  , p=0.0168  , df=1
# likelihood ratio test: chi2=5.7078  , p=0.0169  , df=1
# parameter F test:         F=5.7071  , p=0.0170  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.3895  , p=0.0047  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=10.8221 , p=0.0045  , df=2
# likelihood ratio test: chi2=10.7758 , p=0.0046  , df=2
# parameter F test:         F=5.3895  , p=0.0047  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.9093  , p=0.0086  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=11.7938 , p=0.0081  , df=3
# likelihood ratio test: chi2=11.7387 , p=0.0083  , df=3
# parameter F test:         F=3.9093  , p=0.0086  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.3516  , p=0.0097  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=13.5034 , p=0.0091  , df=4
# likelihood ratio test: chi2=13.4312 , p=0.0094  , df=4
# parameter F test:         F=3.3516  , p=0.0097  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.8387  , p=0.0148  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=14.3193 , p=0.0137  , df=5
# likelihood ratio test: chi2=14.2382 , p=0.0142  , df=5
# parameter F test:         F=2.8387  , p=0.0148  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.6859  , p=0.0012  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=22.3472 , p=0.0010  , df=6
# likelihood ratio test: chi2=22.1502 , p=0.0011  , df=6
# parameter F test:         F=3.6859  , p=0.0012  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9407  , p=0.0047  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=20.8343 , p=0.0040  , df=7
# likelihood ratio test: chi2=20.6629 , p=0.0043  , df=7
# parameter F test:         F=2.9407  , p=0.0047  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.6313  , p=0.0074  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=21.3403 , p=0.0063  , df=8
# likelihood ratio test: chi2=21.1603 , p=0.0067  , df=8
# parameter F test:         F=2.6313  , p=0.0074  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.5306  , p=0.0071  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=23.1269 , p=0.0059  , df=9
# likelihood ratio test: chi2=22.9155 , p=0.0064  , df=9
# parameter F test:         F=2.5306  , p=0.0071  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.5762  , p=0.0044  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=26.2029 , p=0.0035  , df=10
# likelihood ratio test: chi2=25.9318 , p=0.0038  , df=10
# parameter F test:         F=2.5762  , p=0.0044  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9108  , p=0.1671  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=1.9154  , p=0.1664  , df=1
# likelihood ratio test: chi2=1.9139  , p=0.1665  , df=1
# parameter F test:         F=1.9108  , p=0.1671  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6810  , p=0.1866  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=3.3755  , p=0.1849  , df=2
# likelihood ratio test: chi2=3.3710  , p=0.1854  , df=2
# parameter F test:         F=1.6810  , p=0.1866  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3150  , p=0.2680  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=3.9670  , p=0.2650  , df=3
# likelihood ratio test: chi2=3.9608  , p=0.2657  , df=3
# parameter F test:         F=1.3150  , p=0.2680  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2059  , p=0.3065  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=4.8584  , p=0.3021  , df=4
# likelihood ratio test: chi2=4.8490  , p=0.3031  , df=4
# parameter F test:         F=1.2059  , p=0.3065  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9799  , p=0.4287  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=4.9428  , p=0.4229  , df=5
# likelihood ratio test: chi2=4.9331  , p=0.4241  , df=5
# parameter F test:         F=0.9799  , p=0.4287  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0494  , p=0.3914  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=6.3625  , p=0.3838  , df=6
# likelihood ratio test: chi2=6.3464  , p=0.3855  , df=6
# parameter F test:         F=1.0494  , p=0.3914  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9771  , p=0.4463  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=6.9230  , p=0.4369  , df=7
# likelihood ratio test: chi2=6.9039  , p=0.4390  , df=7
# parameter F test:         F=0.9771  , p=0.4463  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0359  , p=0.8498  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0360  , p=0.8496  , df=1
# likelihood ratio test: chi2=0.0360  , p=0.8496  , df=1
# parameter F test:         F=0.0359  , p=0.8498  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.6558  , p=0.0036  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=11.3567 , p=0.0034  , df=2
# likelihood ratio test: chi2=11.3057 , p=0.0035  , df=2
# parameter F test:         F=5.6558  , p=0.0036  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.7360  , p=0.0109  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=11.2709 , p=0.0103  , df=3
# likelihood ratio test: chi2=11.2207 , p=0.0106  , df=3
# parameter F test:         F=3.7360  , p=0.0109  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.0850  , p=0.0153  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=12.4290 , p=0.0144  , df=4
# likelihood ratio test: chi2=12.3679 , p=0.0148  , df=4
# parameter F test:         F=3.0850  , p=0.0153  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.4103  , p=0.0046  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=17.2023 , p=0.0041  , df=5
# likelihood ratio test: chi2=17.0854 , p=0.0043  , df=5
# parameter F test:         F=3.4103  , p=0.0046  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.9594  , p=0.0071  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=17.9425 , p=0.0064  , df=6
# likelihood ratio test: chi2=17.8152 , p=0.0067  , df=6
# parameter F test:         F=2.9594  , p=0.0071  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.5229  , p=0.0141  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=17.8745 , p=0.0125  , df=7
# likelihood ratio test: chi2=17.7481 , p=0.0132  , df=7
# parameter F test:         F=2.5229  , p=0.0141  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.0065  , p=0.0024  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=24.3837 , p=0.0020  , df=8
# likelihood ratio test: chi2=24.1491 , p=0.0022  , df=8
# parameter F test:         F=3.0065  , p=0.0024  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4134  , p=0.0103  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=22.0560 , p=0.0087  , df=9
# likelihood ratio test: chi2=21.8636 , p=0.0093  , df=9
# parameter F test:         F=2.4134  , p=0.0103  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.7510  , p=0.0001  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=38.1513 , p=0.0000  , df=10
# likelihood ratio test: chi2=37.5802 , p=0.0000  , df=10
# parameter F test:         F=3.7510  , p=0.0001  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1202  , p=0.7288  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.1205  , p=0.7285  , df=1
# likelihood ratio test: chi2=0.1205  , p=0.7285  , df=1
# parameter F test:         F=0.1202  , p=0.7288  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5846  , p=0.5575  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=1.1738  , p=0.5560  , df=2
# likelihood ratio test: chi2=1.1733  , p=0.5562  , df=2
# parameter F test:         F=0.5846  , p=0.5575  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4422  , p=0.7229  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=1.3339  , p=0.7211  , df=3
# likelihood ratio test: chi2=1.3332  , p=0.7213  , df=3
# parameter F test:         F=0.4422  , p=0.7229  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8441  , p=0.4972  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=3.4008  , p=0.4931  , df=4
# likelihood ratio test: chi2=3.3962  , p=0.4938  , df=4
# parameter F test:         F=0.8441  , p=0.4972  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9141  , p=0.4709  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=4.6110  , p=0.4652  , df=5
# likelihood ratio test: chi2=4.6025  , p=0.4663  , df=5
# parameter F test:         F=0.9141  , p=0.4709  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7850  , p=0.5817  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=4.7594  , p=0.5750  , df=6
# likelihood ratio test: chi2=4.7504  , p=0.5762  , df=6
# parameter F test:         F=0.7850  , p=0.5817  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4819  , p=0.1696  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=10.4988 , p=0.1620  , df=7
# likelihood ratio test: chi2=10.4550 , p=0.1642  , df=7
# parameter F test:         F=1.4819  , p=0.1696  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3671  , p=0.0157  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=19.1980 , p=0.0138  , df=8
# likelihood ratio test: chi2=19.0522 , p=0.0146  , df=8
# parameter F test:         F=2.3671  , p=0.0157  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0453  , p=0.0316  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=18.6915 , p=0.0279  , df=9
# likelihood ratio test: chi2=18.5531 , p=0.0293  , df=9
# parameter F test:         F=2.0453  , p=0.0316  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.4037  , p=0.0002  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=34.6193 , p=0.0001  , df=10
# likelihood ratio test: chi2=34.1482 , p=0.0002  , df=10
# parameter F test:         F=3.4037  , p=0.0002  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7678  , p=0.3811  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.7696  , p=0.3803  , df=1
# likelihood ratio test: chi2=0.7694  , p=0.3804  , df=1
# parameter F test:         F=0.7678  , p=0.3811  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3076  , p=0.0999  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=4.6337  , p=0.0986  , df=2
# likelihood ratio test: chi2=4.6252  , p=0.0990  , df=2
# parameter F test:         F=2.3076  , p=0.0999  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9814  , p=0.1149  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=5.9775  , p=0.1127  , df=3
# likelihood ratio test: chi2=5.9633  , p=0.1134  , df=3
# parameter F test:         F=1.9814  , p=0.1149  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5453  , p=0.1868  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=6.2257  , p=0.1829  , df=4
# likelihood ratio test: chi2=6.2103  , p=0.1840  , df=4
# parameter F test:         F=1.5453  , p=0.1868  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5940  , p=0.1588  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=8.0404  , p=0.1540  , df=5
# likelihood ratio test: chi2=8.0147  , p=0.1554  , df=5
# parameter F test:         F=1.5940  , p=0.1588  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3306  , p=0.2402  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=8.0676  , p=0.2332  , df=6
# likelihood ratio test: chi2=8.0417  , p=0.2351  , df=6
# parameter F test:         F=1.3306  , p=0.2402  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8610  , p=0.0725  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=13.1848 , p=0.0677  , df=7
# likelihood ratio test: chi2=13.1159 , p=0.0693  , df=7
# parameter F test:         F=1.8610  , p=0.0725  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2707  , p=0.6029  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.2714  , p=0.6024  , df=1
# likelihood ratio test: chi2=0.2713  , p=0.6024  , df=1
# parameter F test:         F=0.2707  , p=0.6029  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3085  , p=0.2706  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.6275  , p=0.2688  , df=2
# likelihood ratio test: chi2=2.6248  , p=0.2692  , df=2
# parameter F test:         F=1.3085  , p=0.2706  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8632  , p=0.4596  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.6042  , p=0.4568  , df=3
# likelihood ratio test: chi2=2.6015  , p=0.4572  , df=3
# parameter F test:         F=0.8632  , p=0.4596  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4792  , p=0.0424  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=9.9884  , p=0.0406  , df=4
# likelihood ratio test: chi2=9.9488  , p=0.0413  , df=4
# parameter F test:         F=2.4792  , p=0.0424  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3035  , p=0.0427  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=11.6196 , p=0.0404  , df=5
# likelihood ratio test: chi2=11.5661 , p=0.0412  , df=5
# parameter F test:         F=2.3035  , p=0.0427  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4010  , p=0.0260  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=14.5569 , p=0.0240  , df=6
# likelihood ratio test: chi2=14.4730 , p=0.0248  , df=6
# parameter F test:         F=2.4010  , p=0.0260  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9420  , p=0.0046  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=20.8435 , p=0.0040  , df=7
# likelihood ratio test: chi2=20.6719 , p=0.0043  , df=7
# parameter F test:         F=2.9420  , p=0.0046  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.8877  , p=0.0002  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=31.5302 , p=0.0001  , df=8
# likelihood ratio test: chi2=31.1394 , p=0.0001  , df=8
# parameter F test:         F=3.8877  , p=0.0002  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.3194  , p=0.0005  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=30.3359 , p=0.0004  , df=9
# likelihood ratio test: chi2=29.9737 , p=0.0004  , df=9
# parameter F test:         F=3.3194  , p=0.0005  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.2042  , p=0.0004  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=32.5899 , p=0.0003  , df=10
# likelihood ratio test: chi2=32.1720 , p=0.0004  , df=10
# parameter F test:         F=3.2042  , p=0.0004  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.8318  , p=0.0012  , df_denom=1225, df_num=11
# ssr based chi2 test:   chi2=31.7348 , p=0.0008  , df=11
# likelihood ratio test: chi2=31.3380 , p=0.0010  , df=11
# parameter F test:         F=2.8318  , p=0.0012  , df_denom=1225, df_num=11
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2589  , p=0.6109  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.2596  , p=0.6104  , df=1
# likelihood ratio test: chi2=0.2595  , p=0.6104  , df=1
# parameter F test:         F=0.2589  , p=0.6109  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1668  , p=0.3117  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.3430  , p=0.3099  , df=2
# likelihood ratio test: chi2=2.3408  , p=0.3102  , df=2
# parameter F test:         F=1.1668  , p=0.3117  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9525  , p=0.4145  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.8734  , p=0.4116  , df=3
# likelihood ratio test: chi2=2.8702  , p=0.4121  , df=3
# parameter F test:         F=0.9525  , p=0.4145  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0517  , p=0.3792  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=4.2372  , p=0.3749  , df=4
# likelihood ratio test: chi2=4.2301  , p=0.3758  , df=4
# parameter F test:         F=1.0517  , p=0.3792  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1584  , p=0.3276  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=5.8434  , p=0.3218  , df=5
# likelihood ratio test: chi2=5.8298  , p=0.3231  , df=5
# parameter F test:         F=1.1584  , p=0.3276  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0378  , p=0.3989  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=6.2920  , p=0.3913  , df=6
# likelihood ratio test: chi2=6.2763  , p=0.3930  , df=6
# parameter F test:         F=1.0378  , p=0.3989  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.3200  , p=0.0236  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=16.4372 , p=0.0214  , df=7
# likelihood ratio test: chi2=16.3302 , p=0.0223  , df=7
# parameter F test:         F=2.3200  , p=0.0236  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3396  , p=0.0170  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=18.9745 , p=0.0150  , df=8
# likelihood ratio test: chi2=18.8320 , p=0.0158  , df=8
# parameter F test:         F=2.3396  , p=0.0170  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0661  , p=0.0297  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=18.8817 , p=0.0262  , df=9
# likelihood ratio test: chi2=18.7406 , p=0.0275  , df=9
# parameter F test:         F=2.0661  , p=0.0297  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8301  , p=0.0513  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=18.6135 , p=0.0455  , df=10
# likelihood ratio test: chi2=18.4762 , p=0.0474  , df=10
# parameter F test:         F=1.8301  , p=0.0513  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0001  , p=0.9927  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0001  , p=0.9927  , df=1
# likelihood ratio test: chi2=0.0001  , p=0.9927  , df=1
# parameter F test:         F=0.0001  , p=0.9927  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2649  , p=0.7673  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=0.5319  , p=0.7665  , df=2
# likelihood ratio test: chi2=0.5318  , p=0.7665  , df=2
# parameter F test:         F=0.2649  , p=0.7673  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2707  , p=0.8465  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=0.8168  , p=0.8455  , df=3
# likelihood ratio test: chi2=0.8165  , p=0.8455  , df=3
# parameter F test:         F=0.2707  , p=0.8465  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2716  , p=0.8964  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=1.0941  , p=0.8952  , df=4
# likelihood ratio test: chi2=1.0936  , p=0.8953  , df=4
# parameter F test:         F=0.2716  , p=0.8964  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5735  , p=0.1646  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=7.9373  , p=0.1597  , df=5
# likelihood ratio test: chi2=7.9123  , p=0.1611  , df=5
# parameter F test:         F=1.5735  , p=0.1646  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4841  , p=0.1800  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=8.9980  , p=0.1737  , df=6
# likelihood ratio test: chi2=8.9659  , p=0.1755  , df=6
# parameter F test:         F=1.4841  , p=0.1800  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1907  , p=0.3049  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=8.4357  , p=0.2957  , df=7
# likelihood ratio test: chi2=8.4074  , p=0.2980  , df=7
# parameter F test:         F=1.1907  , p=0.3049  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1738  , p=0.3114  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=9.5200  , p=0.3003  , df=8
# likelihood ratio test: chi2=9.4839  , p=0.3031  , df=8
# parameter F test:         F=1.1738  , p=0.3114  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2830  , p=0.2414  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=11.7254 , p=0.2292  , df=9
# likelihood ratio test: chi2=11.6707 , p=0.2325  , df=9
# parameter F test:         F=1.2830  , p=0.2414  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2785  , p=0.2374  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=13.0036 , p=0.2235  , df=10
# likelihood ratio test: chi2=12.9363 , p=0.2273  , df=10
# parameter F test:         F=1.2785  , p=0.2374  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0086  , p=0.9262  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0086  , p=0.9261  , df=1
# likelihood ratio test: chi2=0.0086  , p=0.9261  , df=1
# parameter F test:         F=0.0086  , p=0.9262  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5590  , p=0.2107  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=3.1305  , p=0.2090  , df=2
# likelihood ratio test: chi2=3.1266  , p=0.2094  , df=2
# parameter F test:         F=1.5590  , p=0.2107  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0732  , p=0.3594  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=3.2377  , p=0.3564  , df=3
# likelihood ratio test: chi2=3.2336  , p=0.3570  , df=3
# parameter F test:         F=1.0732  , p=0.3594  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.5479  , p=0.0378  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=10.2652 , p=0.0362  , df=4
# likelihood ratio test: chi2=10.2235 , p=0.0368  , df=4
# parameter F test:         F=2.5479  , p=0.0378  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3494  , p=0.0390  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=11.8508 , p=0.0369  , df=5
# likelihood ratio test: chi2=11.7952 , p=0.0377  , df=5
# parameter F test:         F=2.3494  , p=0.0390  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0256  , p=0.0595  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=12.2811 , p=0.0560  , df=6
# likelihood ratio test: chi2=12.2213 , p=0.0572  , df=6
# parameter F test:         F=2.0256  , p=0.0595  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6128  , p=0.1276  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=11.4268 , p=0.1211  , df=7
# likelihood ratio test: chi2=11.3750 , p=0.1231  , df=7
# parameter F test:         F=1.6128  , p=0.1276  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6555  , p=0.1050  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=13.4261 , p=0.0980  , df=8
# likelihood ratio test: chi2=13.3545 , p=0.1002  , df=8
# parameter F test:         F=1.6555  , p=0.1050  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3078  , p=0.2279  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=11.9518 , p=0.2160  , df=9
# likelihood ratio test: chi2=11.8950 , p=0.2193  , df=9
# parameter F test:         F=1.3078  , p=0.2279  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3429  , p=0.2022  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=13.6586 , p=0.1891  , df=10
# likelihood ratio test: chi2=13.5844 , p=0.1928  , df=10
# parameter F test:         F=1.3429  , p=0.2022  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.5893  , p=0.0960  , df_denom=1225, df_num=11
# ...
# ssr based chi2 test:   chi2=3.9670  , p=0.2650  , df=3
# likelihood ratio test: chi2=3.9608  , p=0.2657  , df=3
# parameter F test:         F=1.3150  , p=0.2680  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2059  , p=0.3065  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=4.8584  , p=0.3021  , df=4
# likelihood ratio test: chi2=4.8490  , p=0.3031  , df=4
# parameter F test:         F=1.2059  , p=0.3065  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9799  , p=0.4287  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=4.9428  , p=0.4229  , df=5
# likelihood ratio test: chi2=4.9331  , p=0.4241  , df=5
# parameter F test:         F=0.9799  , p=0.4287  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0494  , p=0.3914  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=6.3625  , p=0.3838  , df=6
# likelihood ratio test: chi2=6.3464  , p=0.3855  , df=6
# parameter F test:         F=1.0494  , p=0.3914  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9771  , p=0.4463  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=6.9230  , p=0.4369  , df=7
# likelihood ratio test: chi2=6.9039  , p=0.4390  , df=7
# parameter F test:         F=0.9771  , p=0.4463  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0359  , p=0.8498  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0360  , p=0.8496  , df=1
# likelihood ratio test: chi2=0.0360  , p=0.8496  , df=1
# parameter F test:         F=0.0359  , p=0.8498  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.6558  , p=0.0036  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=11.3567 , p=0.0034  , df=2
# likelihood ratio test: chi2=11.3057 , p=0.0035  , df=2
# parameter F test:         F=5.6558  , p=0.0036  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.7360  , p=0.0109  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=11.2709 , p=0.0103  , df=3
# likelihood ratio test: chi2=11.2207 , p=0.0106  , df=3
# parameter F test:         F=3.7360  , p=0.0109  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.0850  , p=0.0153  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=12.4290 , p=0.0144  , df=4
# likelihood ratio test: chi2=12.3679 , p=0.0148  , df=4
# parameter F test:         F=3.0850  , p=0.0153  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.4103  , p=0.0046  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=17.2023 , p=0.0041  , df=5
# likelihood ratio test: chi2=17.0854 , p=0.0043  , df=5
# parameter F test:         F=3.4103  , p=0.0046  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.9594  , p=0.0071  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=17.9425 , p=0.0064  , df=6
# likelihood ratio test: chi2=17.8152 , p=0.0067  , df=6
# parameter F test:         F=2.9594  , p=0.0071  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.5229  , p=0.0141  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=17.8745 , p=0.0125  , df=7
# likelihood ratio test: chi2=17.7481 , p=0.0132  , df=7
# parameter F test:         F=2.5229  , p=0.0141  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.0065  , p=0.0024  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=24.3837 , p=0.0020  , df=8
# likelihood ratio test: chi2=24.1491 , p=0.0022  , df=8
# parameter F test:         F=3.0065  , p=0.0024  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4134  , p=0.0103  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=22.0560 , p=0.0087  , df=9
# likelihood ratio test: chi2=21.8636 , p=0.0093  , df=9
# parameter F test:         F=2.4134  , p=0.0103  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.7510  , p=0.0001  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=38.1513 , p=0.0000  , df=10
# likelihood ratio test: chi2=37.5802 , p=0.0000  , df=10
# parameter F test:         F=3.7510  , p=0.0001  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1202  , p=0.7288  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.1205  , p=0.7285  , df=1
# likelihood ratio test: chi2=0.1205  , p=0.7285  , df=1
# parameter F test:         F=0.1202  , p=0.7288  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5846  , p=0.5575  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=1.1738  , p=0.5560  , df=2
# likelihood ratio test: chi2=1.1733  , p=0.5562  , df=2
# parameter F test:         F=0.5846  , p=0.5575  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4422  , p=0.7229  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=1.3339  , p=0.7211  , df=3
# likelihood ratio test: chi2=1.3332  , p=0.7213  , df=3
# parameter F test:         F=0.4422  , p=0.7229  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8441  , p=0.4972  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=3.4008  , p=0.4931  , df=4
# likelihood ratio test: chi2=3.3962  , p=0.4938  , df=4
# parameter F test:         F=0.8441  , p=0.4972  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9141  , p=0.4709  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=4.6110  , p=0.4652  , df=5
# likelihood ratio test: chi2=4.6025  , p=0.4663  , df=5
# parameter F test:         F=0.9141  , p=0.4709  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7850  , p=0.5817  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=4.7594  , p=0.5750  , df=6
# likelihood ratio test: chi2=4.7504  , p=0.5762  , df=6
# parameter F test:         F=0.7850  , p=0.5817  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4819  , p=0.1696  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=10.4988 , p=0.1620  , df=7
# likelihood ratio test: chi2=10.4550 , p=0.1642  , df=7
# parameter F test:         F=1.4819  , p=0.1696  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3671  , p=0.0157  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=19.1980 , p=0.0138  , df=8
# likelihood ratio test: chi2=19.0522 , p=0.0146  , df=8
# parameter F test:         F=2.3671  , p=0.0157  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0453  , p=0.0316  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=18.6915 , p=0.0279  , df=9
# likelihood ratio test: chi2=18.5531 , p=0.0293  , df=9
# parameter F test:         F=2.0453  , p=0.0316  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.4037  , p=0.0002  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=34.6193 , p=0.0001  , df=10
# likelihood ratio test: chi2=34.1482 , p=0.0002  , df=10
# parameter F test:         F=3.4037  , p=0.0002  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7678  , p=0.3811  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.7696  , p=0.3803  , df=1
# likelihood ratio test: chi2=0.7694  , p=0.3804  , df=1
# parameter F test:         F=0.7678  , p=0.3811  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3076  , p=0.0999  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=4.6337  , p=0.0986  , df=2
# likelihood ratio test: chi2=4.6252  , p=0.0990  , df=2
# parameter F test:         F=2.3076  , p=0.0999  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9814  , p=0.1149  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=5.9775  , p=0.1127  , df=3
# likelihood ratio test: chi2=5.9633  , p=0.1134  , df=3
# parameter F test:         F=1.9814  , p=0.1149  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5453  , p=0.1868  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=6.2257  , p=0.1829  , df=4
# likelihood ratio test: chi2=6.2103  , p=0.1840  , df=4
# parameter F test:         F=1.5453  , p=0.1868  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5940  , p=0.1588  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=8.0404  , p=0.1540  , df=5
# likelihood ratio test: chi2=8.0147  , p=0.1554  , df=5
# parameter F test:         F=1.5940  , p=0.1588  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3306  , p=0.2402  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=8.0676  , p=0.2332  , df=6
# likelihood ratio test: chi2=8.0417  , p=0.2351  , df=6
# parameter F test:         F=1.3306  , p=0.2402  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8610  , p=0.0725  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=13.1848 , p=0.0677  , df=7
# likelihood ratio test: chi2=13.1159 , p=0.0693  , df=7
# parameter F test:         F=1.8610  , p=0.0725  , df_denom=1237, df_num=7
# /var/folders/nx/scf6msw549j5lvz4kv2gfpz00000gn/T/ipykernel_34586/4017163888.py:7: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = results_df.style.applymap(highlight_table_cells)
# <style type="text/css">
# #T_8d3ed_row0_col0, #T_8d3ed_row0_col1, #T_8d3ed_row0_col2, #T_8d3ed_row1_col0, #T_8d3ed_row1_col1, #T_8d3ed_row1_col2, #T_8d3ed_row1_col3, #T_8d3ed_row1_col4, #T_8d3ed_row1_col5, #T_8d3ed_row1_col9, #T_8d3ed_row1_col10, #T_8d3ed_row2_col0, #T_8d3ed_row2_col1, #T_8d3ed_row2_col2, #T_8d3ed_row2_col3, #T_8d3ed_row2_col4, #T_8d3ed_row2_col5, #T_8d3ed_row2_col6, #T_8d3ed_row2_col7, #T_8d3ed_row2_col8, #T_8d3ed_row2_col9, #T_8d3ed_row2_col10, #T_8d3ed_row3_col0, #T_8d3ed_row3_col1, #T_8d3ed_row3_col2, #T_8d3ed_row3_col5, #T_8d3ed_row3_col6, #T_8d3ed_row3_col7, #T_8d3ed_row3_col8, #T_8d3ed_row3_col9, #T_8d3ed_row3_col10, #T_8d3ed_row4_col0, #T_8d3ed_row4_col1, #T_8d3ed_row4_col2, #T_8d3ed_row4_col4, #T_8d3ed_row4_col5, #T_8d3ed_row4_col6, #T_8d3ed_row4_col7, #T_8d3ed_row4_col8, #T_8d3ed_row4_col9, #T_8d3ed_row4_col10, #T_8d3ed_row5_col0, #T_8d3ed_row5_col1, #T_8d3ed_row5_col2, #T_8d3ed_row5_col3, #T_8d3ed_row5_col4, #T_8d3ed_row5_col5, #T_8d3ed_row5_col6, #T_8d3ed_row5_col7, #T_8d3ed_row5_col8, #T_8d3ed_row5_col9, #T_8d3ed_row5_col10, #T_8d3ed_row6_col0, #T_8d3ed_row6_col3, #T_8d3ed_row6_col4, #T_8d3ed_row6_col5, #T_8d3ed_row6_col6, #T_8d3ed_row6_col7, #T_8d3ed_row6_col8, #T_8d3ed_row6_col9, #T_8d3ed_row6_col10, #T_8d3ed_row7_col10, #T_8d3ed_row8_col0, #T_8d3ed_row8_col1, #T_8d3ed_row8_col2, #T_8d3ed_row8_col3, #T_8d3ed_row8_col4, #T_8d3ed_row8_col5, #T_8d3ed_row8_col6, #T_8d3ed_row8_col7, #T_8d3ed_row8_col8, #T_8d3ed_row8_col9, #T_8d3ed_row8_col10, #T_8d3ed_row9_col0, #T_8d3ed_row9_col10, #T_8d3ed_row10_col0, #T_8d3ed_row10_col1, #T_8d3ed_row10_col2, #T_8d3ed_row10_col3, #T_8d3ed_row10_col4, #T_8d3ed_row10_col5, #T_8d3ed_row10_col6, #T_8d3ed_row10_col10, #T_8d3ed_row11_col0, #T_8d3ed_row11_col1, #T_8d3ed_row11_col2, #T_8d3ed_row11_col3, #T_8d3ed_row11_col4, #T_8d3ed_row11_col5, #T_8d3ed_row11_col6, #T_8d3ed_row11_col7, #T_8d3ed_row11_col8, #T_8d3ed_row11_col9, #T_8d3ed_row11_col10, #T_8d3ed_row12_col0, #T_8d3ed_row12_col1, #T_8d3ed_row12_col2, #T_8d3ed_row13_col0, #T_8d3ed_row13_col1, #T_8d3ed_row13_col2, #T_8d3ed_row13_col3, #T_8d3ed_row13_col4, #T_8d3ed_row13_col5, #T_8d3ed_row13_col9, #T_8d3ed_row13_col10, #T_8d3ed_row14_col0, #T_8d3ed_row14_col1, #T_8d3ed_row14_col2, #T_8d3ed_row14_col3, #T_8d3ed_row14_col4, #T_8d3ed_row14_col5, #T_8d3ed_row14_col6, #T_8d3ed_row14_col7, #T_8d3ed_row14_col8, #T_8d3ed_row14_col9, #T_8d3ed_row14_col10, #T_8d3ed_row15_col0, #T_8d3ed_row15_col1, #T_8d3ed_row15_col2, #T_8d3ed_row15_col5, #T_8d3ed_row15_col6, #T_8d3ed_row15_col7, #T_8d3ed_row15_col8, #T_8d3ed_row15_col9, #T_8d3ed_row15_col10, #T_8d3ed_row16_col0, #T_8d3ed_row16_col1, #T_8d3ed_row16_col2, #T_8d3ed_row16_col4, #T_8d3ed_row16_col5, #T_8d3ed_row16_col6, #T_8d3ed_row16_col7, #T_8d3ed_row16_col8, #T_8d3ed_row16_col9, #T_8d3ed_row16_col10, #T_8d3ed_row17_col0, #T_8d3ed_row17_col1, #T_8d3ed_row17_col2, #T_8d3ed_row17_col3, #T_8d3ed_row17_col4, #T_8d3ed_row17_col5, #T_8d3ed_row17_col6, #T_8d3ed_row17_col7, #T_8d3ed_row17_col8, #T_8d3ed_row17_col9, #T_8d3ed_row17_col10, #T_8d3ed_row18_col0, #T_8d3ed_row18_col3, #T_8d3ed_row18_col4, #T_8d3ed_row18_col5, #T_8d3ed_row18_col6, #T_8d3ed_row18_col7, #T_8d3ed_row18_col8, #T_8d3ed_row18_col9, #T_8d3ed_row18_col10, #T_8d3ed_row19_col10, #T_8d3ed_row20_col0, #T_8d3ed_row20_col1, #T_8d3ed_row20_col2, #T_8d3ed_row20_col3, #T_8d3ed_row20_col4, #T_8d3ed_row20_col5, #T_8d3ed_row20_col6, #T_8d3ed_row20_col7, #T_8d3ed_row20_col8, #T_8d3ed_row20_col9, #T_8d3ed_row20_col10, #T_8d3ed_row21_col0, #T_8d3ed_row21_col10, #T_8d3ed_row22_col0, #T_8d3ed_row22_col1, #T_8d3ed_row22_col2, #T_8d3ed_row22_col3, #T_8d3ed_row22_col4, #T_8d3ed_row22_col5, #T_8d3ed_row22_col6, #T_8d3ed_row22_col10, #T_8d3ed_row23_col0, #T_8d3ed_row23_col1, #T_8d3ed_row23_col2, #T_8d3ed_row23_col3, #T_8d3ed_row23_col4, #T_8d3ed_row23_col5, #T_8d3ed_row23_col6, #T_8d3ed_row23_col7, #T_8d3ed_row23_col8, #T_8d3ed_row23_col9, #T_8d3ed_row23_col10, #T_8d3ed_row24_col0, #T_8d3ed_row24_col1, #T_8d3ed_row24_col2, #T_8d3ed_row25_col0, #T_8d3ed_row25_col1,  ...
#   background-color: transparent;
# }
# #T_8d3ed_row0_col3, #T_8d3ed_row0_col4, #T_8d3ed_row0_col5, #T_8d3ed_row0_col6, #T_8d3ed_row0_col7, #T_8d3ed_row0_col8, #T_8d3ed_row0_col9, #T_8d3ed_row0_col10, #T_8d3ed_row1_col6, #T_8d3ed_row1_col7, #T_8d3ed_row1_col8, #T_8d3ed_row3_col3, #T_8d3ed_row3_col4, #T_8d3ed_row4_col3, #T_8d3ed_row6_col1, #T_8d3ed_row6_col2, #T_8d3ed_row7_col0, #T_8d3ed_row7_col1, #T_8d3ed_row7_col2, #T_8d3ed_row7_col3, #T_8d3ed_row7_col4, #T_8d3ed_row7_col5, #T_8d3ed_row7_col6, #T_8d3ed_row7_col7, #T_8d3ed_row7_col8, #T_8d3ed_row7_col9, #T_8d3ed_row9_col1, #T_8d3ed_row9_col2, #T_8d3ed_row9_col3, #T_8d3ed_row9_col4, #T_8d3ed_row9_col5, #T_8d3ed_row9_col6, #T_8d3ed_row9_col7, #T_8d3ed_row9_col8, #T_8d3ed_row9_col9, #T_8d3ed_row10_col7, #T_8d3ed_row10_col8, #T_8d3ed_row10_col9, #T_8d3ed_row12_col3, #T_8d3ed_row12_col4, #T_8d3ed_row12_col5, #T_8d3ed_row12_col6, #T_8d3ed_row12_col7, #T_8d3ed_row12_col8, #T_8d3ed_row12_col9, #T_8d3ed_row12_col10, #T_8d3ed_row13_col6, #T_8d3ed_row13_col7, #T_8d3ed_row13_col8, #T_8d3ed_row15_col3, #T_8d3ed_row15_col4, #T_8d3ed_row16_col3, #T_8d3ed_row18_col1, #T_8d3ed_row18_col2, #T_8d3ed_row19_col0, #T_8d3ed_row19_col1, #T_8d3ed_row19_col2, #T_8d3ed_row19_col3, #T_8d3ed_row19_col4, #T_8d3ed_row19_col5, #T_8d3ed_row19_col6, #T_8d3ed_row19_col7, #T_8d3ed_row19_col8, #T_8d3ed_row19_col9, #T_8d3ed_row21_col1, #T_8d3ed_row21_col2, #T_8d3ed_row21_col3, #T_8d3ed_row21_col4, #T_8d3ed_row21_col5, #T_8d3ed_row21_col6, #T_8d3ed_row21_col7, #T_8d3ed_row21_col8, #T_8d3ed_row21_col9, #T_8d3ed_row22_col7, #T_8d3ed_row22_col8, #T_8d3ed_row22_col9, #T_8d3ed_row24_col3, #T_8d3ed_row24_col4, #T_8d3ed_row24_col5, #T_8d3ed_row24_col6, #T_8d3ed_row24_col7, #T_8d3ed_row24_col8, #T_8d3ed_row24_col9, #T_8d3ed_row24_col10, #T_8d3ed_row25_col6, #T_8d3ed_row25_col7, #T_8d3ed_row25_col8, #T_8d3ed_row27_col3, #T_8d3ed_row27_col4, #T_8d3ed_row28_col3, #T_8d3ed_row30_col1, #T_8d3ed_row30_col2, #T_8d3ed_row31_col0, #T_8d3ed_row31_col1, #T_8d3ed_row31_col2, #T_8d3ed_row31_col3, #T_8d3ed_row31_col4, #T_8d3ed_row31_col5, #T_8d3ed_row31_col6, #T_8d3ed_row3

# %%
results_df_5y = granger_causality_test(data_log, tickers, periods=['5y'], max_lag=12)
styled_df = results_df.style.applymap(highlight_table_cells)
styled_df
# Out:
# ['5y']
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2707  , p=0.6029  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.2714  , p=0.6024  , df=1
# likelihood ratio test: chi2=0.2713  , p=0.6024  , df=1
# parameter F test:         F=0.2707  , p=0.6029  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3085  , p=0.2706  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.6275  , p=0.2688  , df=2
# likelihood ratio test: chi2=2.6248  , p=0.2692  , df=2
# parameter F test:         F=1.3085  , p=0.2706  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8632  , p=0.4596  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.6042  , p=0.4568  , df=3
# likelihood ratio test: chi2=2.6015  , p=0.4572  , df=3
# parameter F test:         F=0.8632  , p=0.4596  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4792  , p=0.0424  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=9.9884  , p=0.0406  , df=4
# likelihood ratio test: chi2=9.9488  , p=0.0413  , df=4
# parameter F test:         F=2.4792  , p=0.0424  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3035  , p=0.0427  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=11.6196 , p=0.0404  , df=5
# likelihood ratio test: chi2=11.5661 , p=0.0412  , df=5
# parameter F test:         F=2.3035  , p=0.0427  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4010  , p=0.0260  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=14.5569 , p=0.0240  , df=6
# likelihood ratio test: chi2=14.4730 , p=0.0248  , df=6
# parameter F test:         F=2.4010  , p=0.0260  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9420  , p=0.0046  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=20.8435 , p=0.0040  , df=7
# likelihood ratio test: chi2=20.6719 , p=0.0043  , df=7
# parameter F test:         F=2.9420  , p=0.0046  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.8877  , p=0.0002  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=31.5302 , p=0.0001  , df=8
# likelihood ratio test: chi2=31.1394 , p=0.0001  , df=8
# parameter F test:         F=3.8877  , p=0.0002  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.3194  , p=0.0005  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=30.3359 , p=0.0004  , df=9
# likelihood ratio test: chi2=29.9737 , p=0.0004  , df=9
# parameter F test:         F=3.3194  , p=0.0005  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.2042  , p=0.0004  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=32.5899 , p=0.0003  , df=10
# likelihood ratio test: chi2=32.1720 , p=0.0004  , df=10
# parameter F test:         F=3.2042  , p=0.0004  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.8318  , p=0.0012  , df_denom=1225, df_num=11
# ssr based chi2 test:   chi2=31.7348 , p=0.0008  , df=11
# likelihood ratio test: chi2=31.3380 , p=0.0010  , df=11
# parameter F test:         F=2.8318  , p=0.0012  , df_denom=1225, df_num=11
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2589  , p=0.6109  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.2596  , p=0.6104  , df=1
# likelihood ratio test: chi2=0.2595  , p=0.6104  , df=1
# parameter F test:         F=0.2589  , p=0.6109  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1668  , p=0.3117  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.3430  , p=0.3099  , df=2
# likelihood ratio test: chi2=2.3408  , p=0.3102  , df=2
# parameter F test:         F=1.1668  , p=0.3117  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9525  , p=0.4145  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.8734  , p=0.4116  , df=3
# likelihood ratio test: chi2=2.8702  , p=0.4121  , df=3
# parameter F test:         F=0.9525  , p=0.4145  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0517  , p=0.3792  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=4.2372  , p=0.3749  , df=4
# likelihood ratio test: chi2=4.2301  , p=0.3758  , df=4
# parameter F test:         F=1.0517  , p=0.3792  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1584  , p=0.3276  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=5.8434  , p=0.3218  , df=5
# likelihood ratio test: chi2=5.8298  , p=0.3231  , df=5
# parameter F test:         F=1.1584  , p=0.3276  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0378  , p=0.3989  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=6.2920  , p=0.3913  , df=6
# likelihood ratio test: chi2=6.2763  , p=0.3930  , df=6
# parameter F test:         F=1.0378  , p=0.3989  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.3200  , p=0.0236  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=16.4372 , p=0.0214  , df=7
# likelihood ratio test: chi2=16.3302 , p=0.0223  , df=7
# parameter F test:         F=2.3200  , p=0.0236  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3396  , p=0.0170  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=18.9745 , p=0.0150  , df=8
# likelihood ratio test: chi2=18.8320 , p=0.0158  , df=8
# parameter F test:         F=2.3396  , p=0.0170  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0661  , p=0.0297  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=18.8817 , p=0.0262  , df=9
# likelihood ratio test: chi2=18.7406 , p=0.0275  , df=9
# parameter F test:         F=2.0661  , p=0.0297  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8301  , p=0.0513  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=18.6135 , p=0.0455  , df=10
# likelihood ratio test: chi2=18.4762 , p=0.0474  , df=10
# parameter F test:         F=1.8301  , p=0.0513  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0001  , p=0.9927  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0001  , p=0.9927  , df=1
# likelihood ratio test: chi2=0.0001  , p=0.9927  , df=1
# parameter F test:         F=0.0001  , p=0.9927  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2649  , p=0.7673  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=0.5319  , p=0.7665  , df=2
# likelihood ratio test: chi2=0.5318  , p=0.7665  , df=2
# parameter F test:         F=0.2649  , p=0.7673  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2707  , p=0.8465  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=0.8168  , p=0.8455  , df=3
# likelihood ratio test: chi2=0.8165  , p=0.8455  , df=3
# parameter F test:         F=0.2707  , p=0.8465  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2716  , p=0.8964  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=1.0941  , p=0.8952  , df=4
# likelihood ratio test: chi2=1.0936  , p=0.8953  , df=4
# parameter F test:         F=0.2716  , p=0.8964  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5735  , p=0.1646  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=7.9373  , p=0.1597  , df=5
# likelihood ratio test: chi2=7.9123  , p=0.1611  , df=5
# parameter F test:         F=1.5735  , p=0.1646  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4841  , p=0.1800  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=8.9980  , p=0.1737  , df=6
# likelihood ratio test: chi2=8.9659  , p=0.1755  , df=6
# parameter F test:         F=1.4841  , p=0.1800  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1907  , p=0.3049  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=8.4357  , p=0.2957  , df=7
# likelihood ratio test: chi2=8.4074  , p=0.2980  , df=7
# parameter F test:         F=1.1907  , p=0.3049  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1738  , p=0.3114  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=9.5200  , p=0.3003  , df=8
# likelihood ratio test: chi2=9.4839  , p=0.3031  , df=8
# parameter F test:         F=1.1738  , p=0.3114  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2830  , p=0.2414  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=11.7254 , p=0.2292  , df=9
# likelihood ratio test: chi2=11.6707 , p=0.2325  , df=9
# parameter F test:         F=1.2830  , p=0.2414  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2785  , p=0.2374  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=13.0036 , p=0.2235  , df=10
# likelihood ratio test: chi2=12.9363 , p=0.2273  , df=10
# parameter F test:         F=1.2785  , p=0.2374  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0086  , p=0.9262  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0086  , p=0.9261  , df=1
# likelihood ratio test: chi2=0.0086  , p=0.9261  , df=1
# parameter F test:         F=0.0086  , p=0.9262  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5590  , p=0.2107  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=3.1305  , p=0.2090  , df=2
# likelihood ratio test: chi2=3.1266  , p=0.2094  , df=2
# parameter F test:         F=1.5590  , p=0.2107  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0732  , p=0.3594  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=3.2377  , p=0.3564  , df=3
# likelihood ratio test: chi2=3.2336  , p=0.3570  , df=3
# parameter F test:         F=1.0732  , p=0.3594  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.5479  , p=0.0378  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=10.2652 , p=0.0362  , df=4
# likelihood ratio test: chi2=10.2235 , p=0.0368  , df=4
# parameter F test:         F=2.5479  , p=0.0378  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3494  , p=0.0390  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=11.8508 , p=0.0369  , df=5
# likelihood ratio test: chi2=11.7952 , p=0.0377  , df=5
# parameter F test:         F=2.3494  , p=0.0390  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0256  , p=0.0595  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=12.2811 , p=0.0560  , df=6
# likelihood ratio test: chi2=12.2213 , p=0.0572  , df=6
# parameter F test:         F=2.0256  , p=0.0595  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6128  , p=0.1276  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=11.4268 , p=0.1211  , df=7
# likelihood ratio test: chi2=11.3750 , p=0.1231  , df=7
# parameter F test:         F=1.6128  , p=0.1276  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6555  , p=0.1050  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=13.4261 , p=0.0980  , df=8
# likelihood ratio test: chi2=13.3545 , p=0.1002  , df=8
# parameter F test:         F=1.6555  , p=0.1050  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3078  , p=0.2279  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=11.9518 , p=0.2160  , df=9
# likelihood ratio test: chi2=11.8950 , p=0.2193  , df=9
# parameter F test:         F=1.3078  , p=0.2279  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3429  , p=0.2022  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=13.6586 , p=0.1891  , df=10
# likelihood ratio test: chi2=13.5844 , p=0.1928  , df=10
# parameter F test:         F=1.3429  , p=0.2022  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.5893  , p=0.0960  , df_denom=1225, df_num=11
# ssr based chi2 test:   chi2=17.8108 , p=0.0861  , df=11
# likelihood ratio test: chi2=17.6849 , p=0.0892  , df=11
# parameter F test:         F=1.5893  , p=0.0960  , df_denom=1225, df_num=11
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7347  , p=0.3915  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.7365  , p=0.3908  , df=1
# likelihood ratio test: chi2=0.7363  , p=0.3909  , df=1
# parameter F test:         F=0.7347  , p=0.3915  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3027  , p=0.2722  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=2.6158  , p=0.2704  , df=2
# likelihood ratio test: chi2=2.6131  , p=0.2708  , df=2
# parameter F test:         F=1.3027  , p=0.2722  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9189  , p=0.4310  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=2.7723  , p=0.4281  , df=3
# likelihood ratio test: chi2=2.7692  , p=0.4286  , df=3
# parameter F test:         F=0.9189  , p=0.4310  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.5151  , p=0.0400  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=10.1332 , p=0.0382  , df=4
# likelihood ratio test: chi2=10.0925 , p=0.0389  , df=4
# parameter F test:         F=2.5151  , p=0.0400  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9813  , p=0.0787  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=9.9942  , p=0.0754  , df=5
# likelihood ratio test: chi2=9.9546  , p=0.0765  , df=5
# parameter F test:         F=1.9813  , p=0.0787  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6138  , p=0.1397  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=9.7843  , p=0.1340  , df=6
# likelihood ratio test: chi2=9.7463  , p=0.1357  , df=6
# parameter F test:         F=1.6138  , p=0.1397  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4846  , p=0.1686  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=10.5184 , p=0.1610  , df=7
# likelihood ratio test: chi2=10.4745 , p=0.1632  , df=7
# parameter F test:         F=1.4846  , p=0.1686  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3133  , p=0.2325  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=10.6514 , p=0.2222  , df=8
# likelihood ratio test: chi2=10.6063 , p=0.2250  , df=8
# parameter F test:         F=1.3133  , p=0.2325  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1199  , p=0.3451  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=10.2347 , p=0.3318  , df=9
# likelihood ratio test: chi2=10.1930 , p=0.3351  , df=9
# parameter F test:         F=1.1199  , p=0.3451  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9945  , p=0.4461  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=10.1147 , p=0.4305  , df=10
# likelihood ratio test: chi2=10.0740 , p=0.4340  , df=10
# parameter F test:         F=0.9945  , p=0.4461  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0115  , p=0.9145  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0116  , p=0.9144  , df=1
# likelihood ratio test: chi2=0.0116  , p=0.9144  , df=1
# parameter F test:         F=0.0115  , p=0.9145  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1207  , p=0.8863  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=0.2424  , p=0.8858  , df=2
# likelihood ratio test: chi2=0.2424  , p=0.8858  , df=2
# parameter F test:         F=0.1207  , p=0.8863  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1236  , p=0.9462  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=0.3727  , p=0.9458  , df=3
# likelihood ratio test: chi2=0.3727  , p=0.9458  , df=3
# parameter F test:         F=0.1236  , p=0.9462  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2403  , p=0.9156  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=0.9681  , p=0.9146  , df=4
# likelihood ratio test: chi2=0.9677  , p=0.9147  , df=4
# parameter F test:         F=0.2403  , p=0.9156  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2495  , p=0.9402  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=1.2585  , p=0.9391  , df=5
# likelihood ratio test: chi2=1.2579  , p=0.9392  , df=5
# parameter F test:         F=0.2495  , p=0.9402  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1779  , p=0.9829  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=1.0787  , p=0.9825  , df=6
# likelihood ratio test: chi2=1.0783  , p=0.9825  , df=6
# parameter F test:         F=0.1779  , p=0.9829  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1972  , p=0.9861  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=1.3973  , p=0.9857  , df=7
# likelihood ratio test: chi2=1.3965  , p=0.9857  , df=7
# parameter F test:         F=0.1972  , p=0.9861  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2044  , p=0.9902  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=1.6580  , p=0.9898  , df=8
# likelihood ratio test: chi2=1.6569  , p=0.9898  , df=8
# parameter F test:         F=0.2044  , p=0.9902  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.2088  , p=0.9932  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=1.9083  , p=0.9928  , df=9
# likelihood ratio test: chi2=1.9068  , p=0.9929  , df=9
# parameter F test:         F=0.2088  , p=0.9932  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.2926  , p=0.9830  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=2.9763  , p=0.9820  , df=10
# likelihood ratio test: chi2=2.9727  , p=0.9821  , df=10
# parameter F test:         F=0.2926  , p=0.9830  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0170  , p=0.1558  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=2.0218  , p=0.1551  , df=1
# likelihood ratio test: chi2=2.0202  , p=0.1552  , df=1
# parameter F test:         F=2.0170  , p=0.1558  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.7663  , p=0.0087  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=9.5707  , p=0.0084  , df=2
# likelihood ratio test: chi2=9.5345  , p=0.0085  , df=2
# parameter F test:         F=4.7663  , p=0.0087  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1666  , p=0.0237  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=9.5531  , p=0.0228  , df=3
# likelihood ratio test: chi2=9.5170  , p=0.0232  , df=3
# parameter F test:         F=3.1666  , p=0.0237  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3369  , p=0.0536  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=9.4150  , p=0.0515  , df=4
# likelihood ratio test: chi2=9.3799  , p=0.0523  , df=4
# parameter F test:         F=2.3369  , p=0.0536  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0381  , p=0.0708  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=10.2807 , p=0.0677  , df=5
# likelihood ratio test: chi2=10.2388 , p=0.0687  , df=5
# parameter F test:         F=2.0381  , p=0.0708  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7124  , p=0.1146  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=10.3819 , p=0.1095  , df=6
# likelihood ratio test: chi2=10.3392 , p=0.1111  , df=6
# parameter F test:         F=1.7124  , p=0.1146  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3215  , p=0.2362  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=9.3629  , p=0.2276  , df=7
# likelihood ratio test: chi2=9.3281  , p=0.2300  , df=7
# parameter F test:         F=1.3215  , p=0.2362  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4909  , p=0.1558  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=12.0917 , p=0.1472  , df=8
# likelihood ratio test: chi2=12.0336 , p=0.1497  , df=8
# parameter F test:         F=1.4909  , p=0.1558  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4016  , p=0.1823  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=12.8093 , p=0.1714  , df=9
# likelihood ratio test: chi2=12.7441 , p=0.1745  , df=9
# parameter F test:         F=1.4016  , p=0.1823  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7385  , p=0.0676  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=17.6818 , p=0.0606  , df=10
# likelihood ratio test: chi2=17.5578 , p=0.0629  , df=10
# parameter F test:         F=1.7385  , p=0.0676  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.7071  , p=0.0170  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=5.7207  , p=0.0168  , df=1
# likelihood ratio test: chi2=5.7078  , p=0.0169  , df=1
# parameter F test:         F=5.7071  , p=0.0170  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.3895  , p=0.0047  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=10.8221 , p=0.0045  , df=2
# likelihood ratio test: chi2=10.7758 , p=0.0046  , df=2
# parameter F test:         F=5.3895  , p=0.0047  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.9093  , p=0.0086  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=11.7938 , p=0.0081  , df=3
# likelihood ratio test: chi2=11.7387 , p=0.0083  , df=3
# parameter F test:         F=3.9093  , p=0.0086  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.3516  , p=0.0097  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=13.5034 , p=0.0091  , df=4
# likelihood ratio test: chi2=13.4312 , p=0.0094  , df=4
# parameter F test:         F=3.3516  , p=0.0097  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.8387  , p=0.0148  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=14.3193 , p=0.0137  , df=5
# likelihood ratio test: chi2=14.2382 , p=0.0142  , df=5
# parameter F test:         F=2.8387  , p=0.0148  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.6859  , p=0.0012  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=22.3472 , p=0.0010  , df=6
# likelihood ratio test: chi2=22.1502 , p=0.0011  , df=6
# parameter F test:         F=3.6859  , p=0.0012  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9407  , p=0.0047  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=20.8343 , p=0.0040  , df=7
# likelihood ratio test: chi2=20.6629 , p=0.0043  , df=7
# parameter F test:         F=2.9407  , p=0.0047  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.6313  , p=0.0074  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=21.3403 , p=0.0063  , df=8
# likelihood ratio test: chi2=21.1603 , p=0.0067  , df=8
# parameter F test:         F=2.6313  , p=0.0074  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.5306  , p=0.0071  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=23.1269 , p=0.0059  , df=9
# likelihood ratio test: chi2=22.9155 , p=0.0064  , df=9
# parameter F test:         F=2.5306  , p=0.0071  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.5762  , p=0.0044  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=26.2029 , p=0.0035  , df=10
# likelihood ratio test: chi2=25.9318 , p=0.0038  , df=10
# parameter F test:         F=2.5762  , p=0.0044  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9108  , p=0.1671  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=1.9154  , p=0.1664  , df=1
# likelihood ratio test: chi2=1.9139  , p=0.1665  , df=1
# parameter F test:         F=1.9108  , p=0.1671  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6810  , p=0.1866  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=3.3755  , p=0.1849  , df=2
# likelihood ratio test: chi2=3.3710  , p=0.1854  , df=2
# parameter F test:         F=1.6810  , p=0.1866  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3150  , p=0.2680  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=3.9670  , p=0.2650  , df=3
# likelihood ratio test: chi2=3.9608  , p=0.2657  , df=3
# parameter F test:         F=1.3150  , p=0.2680  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2059  , p=0.3065  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=4.8584  , p=0.3021  , df=4
# likelihood ratio test: chi2=4.8490  , p=0.3031  , df=4
# parameter F test:         F=1.2059  , p=0.3065  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9799  , p=0.4287  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=4.9428  , p=0.4229  , df=5
# likelihood ratio test: chi2=4.9331  , p=0.4241  , df=5
# parameter F test:         F=0.9799  , p=0.4287  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0494  , p=0.3914  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=6.3625  , p=0.3838  , df=6
# likelihood ratio test: chi2=6.3464  , p=0.3855  , df=6
# parameter F test:         F=1.0494  , p=0.3914  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9771  , p=0.4463  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=6.9230  , p=0.4369  , df=7
# likelihood ratio test: chi2=6.9039  , p=0.4390  , df=7
# parameter F test:         F=0.9771  , p=0.4463  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0359  , p=0.8498  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.0360  , p=0.8496  , df=1
# likelihood ratio test: chi2=0.0360  , p=0.8496  , df=1
# parameter F test:         F=0.0359  , p=0.8498  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.6558  , p=0.0036  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=11.3567 , p=0.0034  , df=2
# likelihood ratio test: chi2=11.3057 , p=0.0035  , df=2
# parameter F test:         F=5.6558  , p=0.0036  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.7360  , p=0.0109  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=11.2709 , p=0.0103  , df=3
# likelihood ratio test: chi2=11.2207 , p=0.0106  , df=3
# parameter F test:         F=3.7360  , p=0.0109  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.0850  , p=0.0153  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=12.4290 , p=0.0144  , df=4
# likelihood ratio test: chi2=12.3679 , p=0.0148  , df=4
# parameter F test:         F=3.0850  , p=0.0153  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.4103  , p=0.0046  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=17.2023 , p=0.0041  , df=5
# likelihood ratio test: chi2=17.0854 , p=0.0043  , df=5
# parameter F test:         F=3.4103  , p=0.0046  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.9594  , p=0.0071  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=17.9425 , p=0.0064  , df=6
# likelihood ratio test: chi2=17.8152 , p=0.0067  , df=6
# parameter F test:         F=2.9594  , p=0.0071  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.5229  , p=0.0141  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=17.8745 , p=0.0125  , df=7
# likelihood ratio test: chi2=17.7481 , p=0.0132  , df=7
# parameter F test:         F=2.5229  , p=0.0141  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.0065  , p=0.0024  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=24.3837 , p=0.0020  , df=8
# likelihood ratio test: chi2=24.1491 , p=0.0022  , df=8
# parameter F test:         F=3.0065  , p=0.0024  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4134  , p=0.0103  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=22.0560 , p=0.0087  , df=9
# likelihood ratio test: chi2=21.8636 , p=0.0093  , df=9
# parameter F test:         F=2.4134  , p=0.0103  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.7510  , p=0.0001  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=38.1513 , p=0.0000  , df=10
# likelihood ratio test: chi2=37.5802 , p=0.0000  , df=10
# parameter F test:         F=3.7510  , p=0.0001  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1202  , p=0.7288  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.1205  , p=0.7285  , df=1
# likelihood ratio test: chi2=0.1205  , p=0.7285  , df=1
# parameter F test:         F=0.1202  , p=0.7288  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5846  , p=0.5575  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=1.1738  , p=0.5560  , df=2
# likelihood ratio test: chi2=1.1733  , p=0.5562  , df=2
# parameter F test:         F=0.5846  , p=0.5575  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4422  , p=0.7229  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=1.3339  , p=0.7211  , df=3
# likelihood ratio test: chi2=1.3332  , p=0.7213  , df=3
# parameter F test:         F=0.4422  , p=0.7229  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8441  , p=0.4972  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=3.4008  , p=0.4931  , df=4
# likelihood ratio test: chi2=3.3962  , p=0.4938  , df=4
# parameter F test:         F=0.8441  , p=0.4972  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9141  , p=0.4709  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=4.6110  , p=0.4652  , df=5
# likelihood ratio test: chi2=4.6025  , p=0.4663  , df=5
# parameter F test:         F=0.9141  , p=0.4709  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7850  , p=0.5817  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=4.7594  , p=0.5750  , df=6
# likelihood ratio test: chi2=4.7504  , p=0.5762  , df=6
# parameter F test:         F=0.7850  , p=0.5817  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4819  , p=0.1696  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=10.4988 , p=0.1620  , df=7
# likelihood ratio test: chi2=10.4550 , p=0.1642  , df=7
# parameter F test:         F=1.4819  , p=0.1696  , df_denom=1237, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3671  , p=0.0157  , df_denom=1234, df_num=8
# ssr based chi2 test:   chi2=19.1980 , p=0.0138  , df=8
# likelihood ratio test: chi2=19.0522 , p=0.0146  , df=8
# parameter F test:         F=2.3671  , p=0.0157  , df_denom=1234, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0453  , p=0.0316  , df_denom=1231, df_num=9
# ssr based chi2 test:   chi2=18.6915 , p=0.0279  , df=9
# likelihood ratio test: chi2=18.5531 , p=0.0293  , df=9
# parameter F test:         F=2.0453  , p=0.0316  , df_denom=1231, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.4037  , p=0.0002  , df_denom=1228, df_num=10
# ssr based chi2 test:   chi2=34.6193 , p=0.0001  , df=10
# likelihood ratio test: chi2=34.1482 , p=0.0002  , df=10
# parameter F test:         F=3.4037  , p=0.0002  , df_denom=1228, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7678  , p=0.3811  , df_denom=1255, df_num=1
# ssr based chi2 test:   chi2=0.7696  , p=0.3803  , df=1
# likelihood ratio test: chi2=0.7694  , p=0.3804  , df=1
# parameter F test:         F=0.7678  , p=0.3811  , df_denom=1255, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3076  , p=0.0999  , df_denom=1252, df_num=2
# ssr based chi2 test:   chi2=4.6337  , p=0.0986  , df=2
# likelihood ratio test: chi2=4.6252  , p=0.0990  , df=2
# parameter F test:         F=2.3076  , p=0.0999  , df_denom=1252, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9814  , p=0.1149  , df_denom=1249, df_num=3
# ssr based chi2 test:   chi2=5.9775  , p=0.1127  , df=3
# likelihood ratio test: chi2=5.9633  , p=0.1134  , df=3
# parameter F test:         F=1.9814  , p=0.1149  , df_denom=1249, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5453  , p=0.1868  , df_denom=1246, df_num=4
# ssr based chi2 test:   chi2=6.2257  , p=0.1829  , df=4
# likelihood ratio test: chi2=6.2103  , p=0.1840  , df=4
# parameter F test:         F=1.5453  , p=0.1868  , df_denom=1246, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5940  , p=0.1588  , df_denom=1243, df_num=5
# ssr based chi2 test:   chi2=8.0404  , p=0.1540  , df=5
# likelihood ratio test: chi2=8.0147  , p=0.1554  , df=5
# parameter F test:         F=1.5940  , p=0.1588  , df_denom=1243, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3306  , p=0.2402  , df_denom=1240, df_num=6
# ssr based chi2 test:   chi2=8.0676  , p=0.2332  , df=6
# likelihood ratio test: chi2=8.0417  , p=0.2351  , df=6
# parameter F test:         F=1.3306  , p=0.2402  , df_denom=1240, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8610  , p=0.0725  , df_denom=1237, df_num=7
# ssr based chi2 test:   chi2=13.1848 , p=0.0677  , df=7
# likelihood ratio test: chi2=13.1159 , p=0.0693  , df=7
# parameter F test:         F=1.8610  , p=0.0725  , df_denom=1237, df_num=7
# /var/folders/nx/scf6msw549j5lvz4kv2gfpz00000gn/T/ipykernel_34586/3744343073.py:2: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = results_df.style.applymap(highlight_table_cells)
# <style type="text/css">
# #T_04016_row0_col0, #T_04016_row0_col1, #T_04016_row0_col2, #T_04016_row1_col0, #T_04016_row1_col1, #T_04016_row1_col2, #T_04016_row1_col3, #T_04016_row1_col4, #T_04016_row1_col5, #T_04016_row1_col9, #T_04016_row1_col10, #T_04016_row2_col0, #T_04016_row2_col1, #T_04016_row2_col2, #T_04016_row2_col3, #T_04016_row2_col4, #T_04016_row2_col5, #T_04016_row2_col6, #T_04016_row2_col7, #T_04016_row2_col8, #T_04016_row2_col9, #T_04016_row2_col10, #T_04016_row3_col0, #T_04016_row3_col1, #T_04016_row3_col2, #T_04016_row3_col5, #T_04016_row3_col6, #T_04016_row3_col7, #T_04016_row3_col8, #T_04016_row3_col9, #T_04016_row3_col10, #T_04016_row4_col0, #T_04016_row4_col1, #T_04016_row4_col2, #T_04016_row4_col4, #T_04016_row4_col5, #T_04016_row4_col6, #T_04016_row4_col7, #T_04016_row4_col8, #T_04016_row4_col9, #T_04016_row4_col10, #T_04016_row5_col0, #T_04016_row5_col1, #T_04016_row5_col2, #T_04016_row5_col3, #T_04016_row5_col4, #T_04016_row5_col5, #T_04016_row5_col6, #T_04016_row5_col7, #T_04016_row5_col8, #T_04016_row5_col9, #T_04016_row5_col10, #T_04016_row6_col0, #T_04016_row6_col3, #T_04016_row6_col4, #T_04016_row6_col5, #T_04016_row6_col6, #T_04016_row6_col7, #T_04016_row6_col8, #T_04016_row6_col9, #T_04016_row6_col10, #T_04016_row7_col10, #T_04016_row8_col0, #T_04016_row8_col1, #T_04016_row8_col2, #T_04016_row8_col3, #T_04016_row8_col4, #T_04016_row8_col5, #T_04016_row8_col6, #T_04016_row8_col7, #T_04016_row8_col8, #T_04016_row8_col9, #T_04016_row8_col10, #T_04016_row9_col0, #T_04016_row9_col10, #T_04016_row10_col0, #T_04016_row10_col1, #T_04016_row10_col2, #T_04016_row10_col3, #T_04016_row10_col4, #T_04016_row10_col5, #T_04016_row10_col6, #T_04016_row10_col10, #T_04016_row11_col0, #T_04016_row11_col1, #T_04016_row11_col2, #T_04016_row11_col3, #T_04016_row11_col4, #T_04016_row11_col5, #T_04016_row11_col6, #T_04016_row11_col7, #T_04016_row11_col8, #T_04016_row11_col9, #T_04016_row11_col10, #T_04016_row12_col0, #T_04016_row12_col1, #T_04016_row12_col2, #T_04016_row13_col0, #T_04016_row13_col1, #T_04016_row13_col2, #T_04016_row13_col3, #T_04016_row13_col4, #T_04016_row13_col5, #T_04016_row13_col9, #T_04016_row13_col10, #T_04016_row14_col0, #T_04016_row14_col1, #T_04016_row14_col2, #T_04016_row14_col3, #T_04016_row14_col4, #T_04016_row14_col5, #T_04016_row14_col6, #T_04016_row14_col7, #T_04016_row14_col8, #T_04016_row14_col9, #T_04016_row14_col10, #T_04016_row15_col0, #T_04016_row15_col1, #T_04016_row15_col2, #T_04016_row15_col5, #T_04016_row15_col6, #T_04016_row15_col7, #T_04016_row15_col8, #T_04016_row15_col9, #T_04016_row15_col10, #T_04016_row16_col0, #T_04016_row16_col1, #T_04016_row16_col2, #T_04016_row16_col4, #T_04016_row16_col5, #T_04016_row16_col6, #T_04016_row16_col7, #T_04016_row16_col8, #T_04016_row16_col9, #T_04016_row16_col10, #T_04016_row17_col0, #T_04016_row17_col1, #T_04016_row17_col2, #T_04016_row17_col3, #T_04016_row17_col4, #T_04016_row17_col5, #T_04016_row17_col6, #T_04016_row17_col7, #T_04016_row17_col8, #T_04016_row17_col9, #T_04016_row17_col10, #T_04016_row18_col0, #T_04016_row18_col3, #T_04016_row18_col4, #T_04016_row18_col5, #T_04016_row18_col6, #T_04016_row18_col7, #T_04016_row18_col8, #T_04016_row18_col9, #T_04016_row18_col10, #T_04016_row19_col10, #T_04016_row20_col0, #T_04016_row20_col1, #T_04016_row20_col2, #T_04016_row20_col3, #T_04016_row20_col4, #T_04016_row20_col5, #T_04016_row20_col6, #T_04016_row20_col7, #T_04016_row20_col8, #T_04016_row20_col9, #T_04016_row20_col10, #T_04016_row21_col0, #T_04016_row21_col10, #T_04016_row22_col0, #T_04016_row22_col1, #T_04016_row22_col2, #T_04016_row22_col3, #T_04016_row22_col4, #T_04016_row22_col5, #T_04016_row22_col6, #T_04016_row22_col10, #T_04016_row23_col0, #T_04016_row23_col1, #T_04016_row23_col2, #T_04016_row23_col3, #T_04016_row23_col4, #T_04016_row23_col5, #T_04016_row23_col6, #T_04016_row23_col7, #T_04016_row23_col8, #T_04016_row23_col9, #T_04016_row23_col10, #T_04016_row24_col0, #T_04016_row24_col1, #T_04016_row24_col2, #T_04016_row25_col0, #T_04016_row25_col1,  ...
#   background-color: transparent;
# }
# #T_04016_row0_col3, #T_04016_row0_col4, #T_04016_row0_col5, #T_04016_row0_col6, #T_04016_row0_col7, #T_04016_row0_col8, #T_04016_row0_col9, #T_04016_row0_col10, #T_04016_row1_col6, #T_04016_row1_col7, #T_04016_row1_col8, #T_04016_row3_col3, #T_04016_row3_col4, #T_04016_row4_col3, #T_04016_row6_col1, #T_04016_row6_col2, #T_04016_row7_col0, #T_04016_row7_col1, #T_04016_row7_col2, #T_04016_row7_col3, #T_04016_row7_col4, #T_04016_row7_col5, #T_04016_row7_col6, #T_04016_row7_col7, #T_04016_row7_col8, #T_04016_row7_col9, #T_04016_row9_col1, #T_04016_row9_col2, #T_04016_row9_col3, #T_04016_row9_col4, #T_04016_row9_col5, #T_04016_row9_col6, #T_04016_row9_col7, #T_04016_row9_col8, #T_04016_row9_col9, #T_04016_row10_col7, #T_04016_row10_col8, #T_04016_row10_col9, #T_04016_row12_col3, #T_04016_row12_col4, #T_04016_row12_col5, #T_04016_row12_col6, #T_04016_row12_col7, #T_04016_row12_col8, #T_04016_row12_col9, #T_04016_row12_col10, #T_04016_row13_col6, #T_04016_row13_col7, #T_04016_row13_col8, #T_04016_row15_col3, #T_04016_row15_col4, #T_04016_row16_col3, #T_04016_row18_col1, #T_04016_row18_col2, #T_04016_row19_col0, #T_04016_row19_col1, #T_04016_row19_col2, #T_04016_row19_col3, #T_04016_row19_col4, #T_04016_row19_col5, #T_04016_row19_col6, #T_04016_row19_col7, #T_04016_row19_col8, #T_04016_row19_col9, #T_04016_row21_col1, #T_04016_row21_col2, #T_04016_row21_col3, #T_04016_row21_col4, #T_04016_row21_col5, #T_04016_row21_col6, #T_04016_row21_col7, #T_04016_row21_col8, #T_04016_row21_col9, #T_04016_row22_col7, #T_04016_row22_col8, #T_04016_row22_col9, #T_04016_row24_col3, #T_04016_row24_col4, #T_04016_row24_col5, #T_04016_row24_col6, #T_04016_row24_col7, #T_04016_row24_col8, #T_04016_row24_col9, #T_04016_row24_col10, #T_04016_row25_col6, #T_04016_row25_col7, #T_04016_row25_col8, #T_04016_row27_col3, #T_04016_row27_col4, #T_04016_row28_col3, #T_04016_row30_col1, #T_04016_row30_col2, #T_04016_row31_col0, #T_04016_row31_col1, #T_04016_row31_col2, #T_04016_row31_col3, #T_04016_row31_col4, #T_04016_row31_col5, #T_04016_row31_col6, #T_04016_row3

# %% [markdown]
# ## Understanding Granger Causality
#
# Statistical Concept: Granger causality is a statistical technique that examines whether past values of one time series (e.g., Stock A) help predict the future values of another time series (e.g., Stock B) beyond simply considering Stock B's own past values.
#
# Not True Causality: It's crucial to remember that Granger causality doesn't imply a direct cause-and-effect relationship in the real-world sense. There might be other factors or complex market dynamics influencing the relationship.
#
# ## Stock Market Example
#
# Let's say the Granger causality test shows that past values of "Stock A" Granger-cause "Stock B".  This could suggest a few possibilities:
#
# Leading Indicator: Changes in Stock A might precede changes in Stock B.  Investors could potentially use Stock A's movements as a signal for potential future movements in Stock B.
#
# Sector Influence: If Stock A and Stock B belong to the same sector, they might react similarly to common industry news or events. Stock A moving first might simply reflect its faster reaction to this shared driver.
#
# Spurious Correlation: It's possible that the detected relationship is coincidental or due to some other hidden variable influencing both stocks.
#
# ## Interpreting Results
#
# Your results table shows p-values for Granger causality tests between various stock pairs over different periods (5y, 1y, 1m) and at different lags. Here's how to generally interpret the p-values:
#
# Lower p-value: A lower p-value (e.g., below 0.05) provides stronger evidence against the null hypothesis of no Granger causality. This suggests a potential predictive relationship worth investigating further.
#
# Higher p-value:  A higher p-value (e.g., above 0.05) offers weaker evidence of Granger causality.
#
# ## Important Considerations
#
# Multiple Lags: Examine the p-values across different lags. A pattern of lower p-values over consecutive lags might indicate a stronger lead-lag relationship.
#
# Visualizations:  Your earlier visualizations would complement this analysis.  Look for visual patterns in the stock charts that might support or refute the causality suggested by the p-values.
#
# Domain Knowledge: Always interpret your results in the context of your understanding of the specific stocks and the market.
#
# ## Example from Table
#
# ### Analyzing AAPL -> MSFT
#
# Here's a breakdown of the AAPL -> MSFT p-values across different periods and lags in your results table:
#
# 5y: The p-values are generally high (above 0.05), with some dips below the threshold at specific lags. This suggests weak evidence of Granger causality over the longer term.
# 1y: Similar to the 5-year results, most p-values are high, indicating a lack of strong Granger causality in the recent year.
# 1m: Again, the p-values are mostly high.
# Interpretation:  Based on these results, there's limited evidence to suggest that the past values of AAPL consistently help predict the future values of MSFT across the analyzed periods.
#
# ### Analyzing MSFT -> AAPL
#
# 5y: The first few lag values (lag_1, lag_2) have relatively high p-values, but there's a potential pattern of lower p-values as the lag increases. This might warrant further investigation.
# 1y: Similar to the 5y trend, the p-values decrease with increasing lag.
# 1m: The pattern observed in longer periods persists.
# Interpretation: The MSFT -> AAPL direction seems to show slightly more potential for Granger causality, especially at higher lags in the 5-year and 1-year periods.  This could indicate a slower reaction of AAPL to potential leading signals from MSFT.  However, it's essential to investigate this further.
#
# ### GOOGL -> META
#
# Let's look at the GOOGL -> META p-values in your table:
#
# 5y: Lower p-values are present across several lags, particularly in the middle of the lag range.
# 1y: The p-values remain low for several lags.
# 1m: In the most recent month, a few low p-values exist.
# Interpretation: There seems to be some evidence suggesting that the past values of GOOGL might help predict future values of META.  This relationship appears somewhat more consistent across the different periods than the AAPL-MSFT pair.
#
# ## Important Reminders
#
# Statistical, Not Causal: Granger causality is a statistical concept. Always consider potential real-world factors that might explain the observed patterns.
# Visualizations: Refer back to your visualizations to see if they visually support the trends suggested by the Granger causality test.
# Domain Knowledge: Your understanding of the tech sector and the dynamics between the companies is crucial for a contextual interpretation.
